# %% [markdown]
# # EX1

# %%
#Step 1. Import the necessary libraries

import pandas as pd

# %%
#Step 2. Import the dataset from this address.

chipo=pd.read_csv("C:\\Users\\lenovo\\Documents\\Downloads\\chipotle.tsv")

# %%
#Step 3. Assign it to a variable called chipo.

chipo
# Out:
#        order_id  quantity                              item_name  \
# 0             1         1           Chips and Fresh Tomato Salsa
# 1             1         1                                   Izze
# 2             1         1                       Nantucket Nectar
# 3             1         1  Chips and Tomatillo-Green Chili Salsa
# 4             2         2                           Chicken Bowl
# ...         ...       ...                                    ...
# 4617       1833         1                          Steak Burrito
# 4618       1833         1                          Steak Burrito
# 4619       1834         1                     Chicken Salad Bowl
# 4620       1834         1                     Chicken Salad Bowl
# 4621       1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#Step 4. See the first 10 entries

chipo.head(10)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#Step 5. What is the number of observations in the dataset?
num_observations = chipo.shape[0]

print(f'The number of observations in the dataset is: {num_observations}')
# Out:
# The number of observations in the dataset is: 4622

# %%
#Step 6. What is the number of columns in the dataset?

num_columns = len(chipo.columns)
print(f'Number of columns: {num_columns}')
# Out:
# Number of columns: 5

# %%
#Step 7. Print the name of all the columns

column_names_list = list(chipo.columns)
print(f'Column names: {column_names_list}')
# Out:
# Column names: [' order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %%
#Step 8. How is the dataset indexed?
chipo.set_index('item_name', inplace=True)

print(chipo.index)
# Out:
# Index(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos', 'Steak Burrito',
#        ...
#        'Carnitas Bowl', 'Chips', 'Bottled Water', 'Chicken Soft Tacos',
#        'Chips and Guacamole', 'Steak Burrito', 'Steak Burrito',
#        'Chicken Salad Bowl', 'Chicken Salad Bowl', 'Chicken Salad Bowl'],
#       dtype='object', name='item_name', length=4622)

# %%
# Step 9. Which was the most-ordered item?
#Step 10. For the most-ordered item, how many items were ordere?

item_totals = chipo.groupby('item_name')['quantity'].sum()

# Find the item with the maximum total quantity
most_ordered_item = item_totals.idxmax()
max_quantity = item_totals.max()

print(f'The most-ordered item is {most_ordered_item} with {max_quantity} orders.')
# Out:
# The most-ordered item is Chicken Bowl with 761 orders.

# %%
#Step 11. What was the most ordered item in the choice_description column?
item_totals = chipo.groupby('choice_description')['quantity'].sum()

# Find the item with the maximum total quantity
most_ordered_item = item_totals.idxmax()
max_quantity = item_totals.max()

print(f'The most-ordered item is {most_ordered_item} with {max_quantity} orders.')
# Out:
# The most-ordered item is [Diet Coke] with 159 orders.

# %%
#Step 12. How many items were orderd in total?

total_items_ordered = chipo['quantity'].sum()

print(f'Total number of items ordered: {total_items_ordered}')
# Out:
# Total number of items ordered: 4972

# %%
#Step 13. Turn the item price into a float
chipo['item_price'] = chipo['item_price'].replace('[\$,]', '', regex=True).astype(float)

print(chipo)
# Out:
#        order_id  quantity                              item_name  \
# 0             1         1           Chips and Fresh Tomato Salsa
# 1             1         1                                   Izze
# 2             1         1                       Nantucket Nectar
# 3             1         1  Chips and Tomatillo-Green Chili Salsa
# 4             2         2                           Chicken Bowl
# ...         ...       ...                                    ...
# 4617       1833         1                          Steak Burrito
# 4618       1833         1                          Steak Burrito
# 4619       1834         1                     Chicken Salad Bowl
# 4620       1834         1                     Chicken Salad Bowl
# 4621       1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
#Step 13.a. Check the item price type
item_price_dtype = chipo['item_price'].dtype

print(f'Item price data type: {item_price_dtype}')
# Out:
# Item price data type: float64

# %%
#Step 13.b. Create a lambda function and change the type of item price
convert_price = lambda x: float

# Apply the lambda function to the 'item_price' column
chipo['item_price'] = chipo['item_price'].apply(convert_price)


#Step 13.c. Check the item price type  


# Check the data type of the 'item_price' column
item_price_dtype = chipo['item_price'].dtype

print(chipo)
print(f'Item price data type: {item_price_dtype}')
# Out:
#        order_id  quantity                              item_name  \
# 0             1         1           Chips and Fresh Tomato Salsa
# 1             1         1                                   Izze
# 2             1         1                       Nantucket Nectar
# 3             1         1  Chips and Tomatillo-Green Chili Salsa
# 4             2         2                           Chicken Bowl
# ...         ...       ...                                    ...
# 4617       1833         1                          Steak Burrito
# 4618       1833         1                          Steak Burrito
# 4619       1834         1                     Chicken Salad Bowl
# 4620       1834         1                     Chicken Salad Bowl
# 4621       1834         1                     Chicken Salad Bowl
#
#                                      choice_description       item_price
# 0                                                   NaN  <class 'float'>
# ...

# %%
#Step 14. How much was the revenue for the period in the dataset?

total_revenue = chipo['item_price'].sum()

print(f'The total revenue for the period in the dataset is: {total_revenue}')
# Out:
# The total revenue for the period in the dataset is: $2.39 $3.39 $3.39 $2.39 $16.98 $10.98 $1.69 $11.75 $9.25 $9.25 $4.45 $8.75 $8.75 $11.25 $4.45 $2.39 $8.49 $8.49 $2.18 $8.75 $4.45 $8.99 $3.39 $10.98 $3.39 $2.39 $8.49 $8.99 $1.09 $8.49 $2.39 $8.99 $1.69 $8.99 $1.09 $8.75 $8.75 $4.45 $2.95 $11.75 $2.15 $4.45 $11.25 $11.75 $8.75 $10.98 $8.99 $3.39 $8.99 $3.99 $8.99 $2.18 $10.98 $1.09 $8.99 $2.39 $9.25 $11.25 $11.75 $2.15 $4.45 $9.25 $11.25 $8.75 $8.99 $8.99 $3.39 $8.99 $10.98 $8.99 $1.69 $8.99 $3.99 $8.75 $4.45 $8.75 $8.75 $2.15 $8.75 $11.25 $2.15 $9.25 $8.75 $8.75 $9.25 $8.49 $8.99 $1.09 $9.25 $2.95 $11.75 $11.75 $9.25 $11.75 $4.45 $9.25 $4.45 $11.75 $8.75 $8.75 $4.45 $8.99 $8.99 $3.99 $8.49 $3.39 $8.99 $1.09 $9.25 $4.45 $8.75 $2.95 $4.45 $2.39 $8.49 $8.99 $8.49 $1.09 $8.99 $3.99 $8.75 $9.25 $4.45 $11.25 $4.45 $8.99 $1.09 $9.25 $2.95 $4.45 $11.75 $4.45 $8.49 $2.39 $10.98 $22.50 $11.75 $4.45 $11.25 $4.45 $11.25 $4.45 $11.25 $11.25 $11.75 $9.25 $4.45 $11.48 $17.98 $1.69 $17.50 $4.45 $8
# ...

# %%
#Step 15. How many orders were made in the period?

# Calculate the total number of orders
num_orders = chipo.shape[0]

print(f'Total number of orders made in the period: {num_orders}')
# Out:
# Total number of orders made in the period: 4622

# %%
#Step 16. What is the average revenue amount per order?
average_revenue = chipo['item_price'].min()

print(f'The average revenue amount per order is: {average_revenue}')
# Out:
# The average revenue amount per order is: $1.09

# %%
#Step 17. How many different items are sold?
# Count the number of different items sold
num_unique_items = chipo['item_name'].nunique()

print(f'Number of different items sold: {num_unique_items}')
# Out:
# Number of different items sold: 50

# %% [markdown]
# # EX3

# %%
#Step 1. Import the necessary libraries
import pandas as pd

# %%
#Step 2. Import the dataset from this address
user=pd.read_csv("C:\\Users\\BANSI\\Downloads\\output (3).csv")

# %%
# Step 3. Assign it to a variable called users and use the 'user_id' as index
user
# Out:
#      index_num  Unnamed: 1 Unnamed: 2     occupation Unnamed: 4
# 0            1          24          M     technician      85711
# 1            2          53          F          other      94043
# 2            3          23          M         writer      32067
# 3            4          24          M     technician      43537
# 4            5          33          F          other      15213
# ..         ...         ...        ...            ...        ...
# 938        939          26          F        student      33319
# 939        940          32          M  administrator       2215
# 940        941          20          M        student      97229
# 941        942          48          F      librarian      78209
# 942        943          22          M        student      77841
#
# [943 rows x 5 columns]

# %%
#Step 4. See the first 25 entrie
user.head(25)
# Out:
#     index_num  Unnamed: 1 Unnamed: 2     occupation Unnamed: 4
# 0           1          24          M     technician      85711
# 1           2          53          F          other      94043
# 2           3          23          M         writer      32067
# 3           4          24          M     technician      43537
# 4           5          33          F          other      15213
# 5           6          42          M      executive      98101
# 6           7          57          M  administrator      91344
# 7           8          36          M  administrator       5201
# 8           9          29          M        student       1002
# 9          10          53          M         lawyer      90703
# 10         11          39          F          other      30329
# 11         12          28          F          other       6405
# 12         13          47          M       educator      29206
# 13         14          45          M      scientist      55106
# ...

# %%
#Step 5. See the last 10 entrie
user.tail(10)
# Out:
#      index_num  Unnamed: 1 Unnamed: 2     occupation Unnamed: 4
# 933        934          61          M       engineer      22902
# 934        935          42          M         doctor      66221
# 935        936          24          M          other      32789
# 936        937          48          M       educator      98072
# 937        938          38          F     technician      55038
# 938        939          26          F        student      33319
# 939        940          32          M  administrator       2215
# 940        941          20          M        student      97229
# 941        942          48          F      librarian      78209
# 942        943          22          M        student      77841

# %%
# Step 6. What is the number of observations in the dataset?

num_observations = user.shape[0]

print(f'The number of observations in the dataset is: {num_observations}')
# Out:
# The number of observations in the dataset is: 943

# %%
# Step 7. What is the number of columns in the dataset

num_columns = len(user.columns)
print(f'Number of columns: {num_columns}')
# Out:
# Number of columns: 5

# %%
# Step 8. Print the name of all the columns
column_names_list = list(user.columns)
print(f'Column names: {column_names_list}')
# Out:
# Column names: ['index_num', 'Unnamed: 1', 'Unnamed: 2', 'occupation', 'Unnamed: 4']

# %%
# Step 9. How is the dataset indexed
user.set_index('occupation', inplace=True)

# Display the index of the DataFrame
print(user.index)
# Out:
# Index(['technician', 'other', 'writer', 'technician', 'other', 'executive',
#        'administrator', 'administrator', 'student', 'lawyer',
#        ...
#        'engineer', 'doctor', 'other', 'educator', 'technician', 'student',
#        'administrator', 'student', 'librarian', 'student'],
#       dtype='object', name='occupation', length=943)

# %%
# Step 10. What is the data type of each column?

print(user.dtypes)
# Out:
# index_num      int64
# Unnamed: 1     int64
# Unnamed: 2    object
# occupation    object
# Unnamed: 4    object
# dtype: object

# %%
 #Step 11. Print only the occupation column
    
print(user['occupation'])
# Out:
# 0         technician
# 1              other
# 2             writer
# 3         technician
# 4              other
#            ...
# 938          student
# 939    administrator
# 940          student
# 941        librarian
# 942          student
# Name: occupation, Length: 943, dtype: object

# %%
#Step 12. How many different occupations are in this dataset?
num_unique_occupations = user['occupation'].nunique()

print(f'There are {num_unique_occupations} different occupations in the dataset.')
# Out:
# There are 21 different occupations in the dataset.

# %%
# Step 13. What is the most frequent occupation?
most_frequent_occupation = user['occupation'].value_counts().idxmax()

print(f'The most frequent occupation is: {most_frequent_occupation}')
# Out:
# The most frequent occupation is: student

# %%
#Step 14. Summarize the DataFrame
# 1. Basic Information
print("Basic Information:")
print(user.info())

# 2. Descriptive Statistics
print("\nDescriptive Statistics:")
print(user.describe())
# Out:
# Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index_num   943 non-null    int64
#  1   Unnamed: 1  943 non-null    int64
#  2   Unnamed: 2  943 non-null    object
#  3   occupation  943 non-null    object
#  4   Unnamed: 4  943 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 37.0+ KB
# None
#
# Descriptive Statistics:
#         index_num  Unnamed: 1
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
#Step 15. Summarize all the columns
summary = user.describe(include='all')

print("Summary of all columns:")
print(summary)
# Out:
# Summary of all columns:
#          index_num  Unnamed: 1 Unnamed: 2 occupation Unnamed: 4
# count   943.000000  943.000000        943        943        943
# unique         NaN         NaN          2         21        795
# top            NaN         NaN          M    student      55414
# freq           NaN         NaN        670        196          9
# mean    472.000000   34.051962        NaN        NaN        NaN
# std     272.364951   12.192740        NaN        NaN        NaN
# min       1.000000    7.000000        NaN        NaN        NaN
# 25%     236.500000   25.000000        NaN        NaN        NaN
# 50%     472.000000   31.000000        NaN        NaN        NaN
# 75%     707.500000   43.000000        NaN        NaN        NaN
# max     943.000000   73.000000        NaN        NaN        NaN

# %%
# Step 16. Summarize only the occupation column
occupation_summary = user['occupation'].describe()

print("Summary of the 'occupation' column:")
print(occupation_summary)
# Out:
# Summary of the 'occupation' column:
# count         943
# unique         21
# top       student
# freq          196
# Name: occupation, dtype: object

# %%
# Step 17. What is the mean age of users
mean_age = user['Unnamed: 1'].mean()

print(f"The mean age of users is: {mean_age}")
# Out:
# The mean age of users is: 34.05196182396607

# %% [markdown]
# # EX3

# %%
import pandas as pd

# Step 2. Download the dataset to your computer and unzip it
food = pd.read_csv("C:\\Users\\lenovo\\Documents\\Downloads\\archive (1)\\en.openfoodfacts.org.products.tsv", sep="\t",low_memory=False)

# %%
# Step 3: Load the TSV file into a DataFrame
f1=pd.DataFrame(food)
f1
# Out:
#                  code                                                url  \
# 0       0000000003087  http://world-en.openfoodfacts.org/product/0000...
# 1       0000000004530  http://world-en.openfoodfacts.org/product/0000...
# 2       0000000004559  http://world-en.openfoodfacts.org/product/0000...
# 3       0000000016087  http://world-en.openfoodfacts.org/product/0000...
# 4       0000000016094  http://world-en.openfoodfacts.org/product/0000...
# ...               ...                                                ...
# 356022       99567453  http://world-en.openfoodfacts.org/product/9956...
# 356023  9970229501521  http://world-en.openfoodfacts.org/product/9970...
# 356024  9977471758307  http://world-en.openfoodfacts.org/product/9977...
# 356025  9980282863788  http://world-en.openfoodfacts.org/product/9980...
# 356026   999990026839  http://world-en.openfoodfacts.org/product/9999...
#
#                            creator   created_t      created_datetime  \
# ...

# %%
# Step 4: Display the first 5 entries of the DataFrame
print("First 5 entries:")
print(f1.head())
# Out:
# First 5 entries:
#             code                                                url  \
# 0  0000000003087  http://world-en.openfoodfacts.org/product/0000...
# 1  0000000004530  http://world-en.openfoodfacts.org/product/0000...
# 2  0000000004559  http://world-en.openfoodfacts.org/product/0000...
# 3  0000000016087  http://world-en.openfoodfacts.org/product/0000...
# 4  0000000016094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %%
# Step 5: Find the number of observations (rows) in the dataset
num_observations = len(f1)
print("\nNumber of observations:", num_observations)
# Out:
# Number of observations: 356027

# %%
# Step 6: Find the number of columns in the dataset
num_columns = len(f1.columns)
print("\nNumber of columns:", num_columns)
# Out:
# Number of columns: 163

# %%
# Step 7: Print the names of all columns
print("\nColumn names:")
print(f1.columns.tolist())
# Out:
# Column names:
# ...

# %%
# Step 8: Find the name of the 105th column
col_105_name = f1.columns[104]
print("\nName of the 105th column:", col_105_name)
# Out:
# Name of the 105th column: -glucose_100g

# %%
# Step 9: Determine the data type of the observations in the 105th column
_105_type = f1.dtypes[104]
print("\nType of observations in the 105th column:", _105_type)
# Out:
# Type of observations in the 105th column: float64

# %%
# Step 10: Understand how the dataset is indexed
print("\nIndexing of the dataset:", f1.index)
# Out:
# Indexing of the dataset: RangeIndex(start=0, stop=356027, step=1)

# %%
# Step 11: Retrieve the product name of the 19th observation
product_name_19th = f1.loc[18, "product_name"]
print("\nProduct name of the 19th observation:", product_name_19th)
# Out:
# Product name of the 19th observation: Lotus Organic Brown Jasmine Rice

# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %%
# Step 1: Import the necessary libraries
import pandas as pd

# %%
# Step 2: Import the dataset from the given address and assign it to a variable called chipo
chipo = pd.read_csv("C:\\Users\\lenovo\\Documents\\Downloads\\chipotle.tsv",sep="\t",low_memory=False)

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# Step 3: Load the TSV file into a DataFrame
d1=pd.DataFrame(chipo)
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# Step 4: How many products cost more than $10.00?
num = (chipo['item_price'] > '$10.00').sum()
num
# Out:
# 4035

# %%
# Step 5: What is the price of each item? Print a DataFrame with only two columns: item_name and item_price
item_prices = chipo[['item_name', 'item_price']].drop_duplicates()
item_prices
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# ...                                     ...        ...
# 4237                    Chips and Guacamole     $8.50
# 4354                       Steak Soft Tacos    $18.50
# 4489                    Chips and Guacamole    $17.80
# 4509                                  Chips     $1.99
# 4510                          Barbacoa Bowl    $11.49
#
# [209 rows x 2 columns]

# %%
# Step 6: Sort by the name of the item
i_sorted = chipo.sort_values(by='item_name')
i_sorted
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description item_price
# 3389                                        [Diet Coke]    $12.98
# 341                                         [Diet Coke]     $6.49
# 1849                                             [Coke]     $6.49
# 1860                                        [Diet Coke]     $6.49
# 2713                                             [Coke]     $6.49
# ...

# %%
# Step 7: What was the quantity of the most expensive item ordered?

# quantity1 = chipo.groupby('item_price').quantity.sum().sort_index(ascending = False).iloc[0]
quantity1=chipo.sort_values(by = "item_price", ascending = False).head(1)
quantity1
# Out:
#       order_id  quantity         item_name  \
# 2624      1042         1  Steak Salad Bowl
#
#                                      choice_description item_price
# 2624  [Fresh Tomato Salsa, [Black Beans, Sour Cream,...     $9.39

# %%
# Step 8: How many times was a Veggie Salad Bowl ordered?
salad_orders = chipo[chipo['item_name'] == 'Veggie Salad Bowl']['quantity'].sum()
salad_orders
# Out:
# 18

# %%
# Step 9: How many times did someone order more than one Canned Soda?
canned_soda_orders = chipo[(chipo['item_name'] == 'Canned Soda') & (chipo['quantity'] > 1)].shape[0]
canned_soda_orders
# Out:
# 20

# %% [markdown]
# # Ex2 - Filtering and Sorting Data

# %%
import pandas as pd
import numpy as np

# %%
# Step 2. Import the dataset from this address.

euro = pd.read_csv('C:\\Users\\lenovo\\Documents\\Downloads\\Euro_2012_stats_TEAM.csv')

# %%
# Step 3. Assign it to a variable called euro12.
euro
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Step 4. Select only the Goal column.
euro.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
# Step 5. How many team participated in the Euro2012?
euro.Team.nunique()
# Out:
# 16

# %%
# Step 6. What is the number of columns in the dataset?
euro.shape[1]
# Out:
# 35

# %%
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
discipline = euro[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
# Step 8. Sort the teams by Red Cards, then to Yellow Cards
discipline.sort_values(by=['Red Cards', 'Yellow Cards'], inplace = True)
discipline
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18736\1426409007.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   discipline.sort_values(by=['Red Cards', 'Yellow Cards'], inplace = True)
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# ...

# %%
# Step 9. Calculate the mean Yellow Cards given per Team
discipline['Yellow Cards'].sum() 
discipline['Yellow Cards'].mean()
# Out:
# 7.4375

# %%
# Step 10. Filter teams that scored more than 6 goals
euro[euro['Goals'] > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
# Step 11. Select the teams that start with G
euro[euro.Team.str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
# Step 12. Select the first 7 columns
euro.head(7)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# ...

# %%
# Step 13. Select all columns except the last 3.
euro.iloc[:, :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Step 14. Present only the Shooting Accuracy from England,Italy and Russia.
euro.loc[euro.Team.isin(['England', 'Italy', 'Russia']),['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%
